# %% [markdown]
# # Report after EuroSciPy 2017
#
# ![EuroSciPy](pic/euroscipy_logo.png)
#
# [//]: # (<div class="stretch"><img src="pic/euroscipy_logo.png"/></div>)
#
#
# ### by Artem Samtsevich

# %% [markdown]
# ## Outline:
#
# * Tutorials
#     - [<span style="font-family:Menlo;">NumPy</span>](http://www.numpy.org)
#     - [<span style="font-family:Menlo;">Matplotlib</span>](http://matplotlib.org)
#     - [<span style="font-family:Menlo;">pandas</span>](https://pandas.pydata.org/)
#     - [<span style="font-family:Menlo;">Git</span>](https://git-scm.com/)
#     - [<span style="font-family:Menlo;">scikit-learn</span>](http://scikit-learn.org/stable/)
# * Testing and test coverage
# * [<span style="font-family:Menlo;">Cython</span>](cython.org)
# * Multicore computing
# * More useful references
# [//]: # (* Some specific topics)
# [//]: # (   - [<span style="font-family:Menlo;">Arcas</span>](https://github.com/ArcasProject/Arcas))
# [//]: # (   - self-publication via Python TEX)
# [//]: # (   - making presentations via Jupyter notebook)
#
#
# [//]: # (- Here's the formula fo $\pi$:)
# [//]: # ($$\pi = \frac{C}{D}$$)

# %% [markdown]
# ## What is EuroSciPy?

# %% [markdown]
# #### 2 days of tutorials
#     - For beginners
#     - Advances
# #### 2 days conference
#
#
# More details [here](https://www.euroscipy.org/2017/program.html)

# %% [markdown]
# ## Tutorials

# %% [markdown]
# ### <span style="font-family:Menlo;">NumPy</span>  (beginners)
# <img src="pic/numpy_logo.png" alt="Numpy logo" style="width: 100px;"/>
#
# #### <span style="font-family:Menlo;">NumPy</span> is the fundamental package for scientific computing with Python. It contains among other things:
#
# * a powerful N-dimensional array object
# * sophisticated (broadcasting) functions
# * tools for integrating C/C++ and Fortran code
# * useful linear algebra, Fourier transform, and random number capabilities
#
# ### [Link](https://github.com/gertingold/euroscipy-numpy-tutorial) to <span style="font-family:Menlo;">Numpy</span> tutorials

# %% [markdown]
# ### Videos of <span style="font-family:Menlo;">Numpy</span> tutorials

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('R2rCYf3pv-M')

# %%
YouTubeVideo('sunNXIxIGV8')

# %% [markdown]
# ### Useful for:
# * everywhere in USPEX code

# %% [markdown]
# ### <span style="font-family:Menlo;">Matplotlib</span> (beginners)
# <img src="pic/matplotlib-1.jpg" alt="matplotlib logo"/>
#
# #### <span style="font-family:Menlo;">Matplotlib</span> is a Python 2D plotting library which produces publication quality figures in a variety of formats

# %% [markdown]
# ### Video of <span style="font-family:Menlo;">Matplotlib</span> tutorials

# %%
YouTubeVideo('YrnHdgZ8n1U')

# %% [markdown]
# ### Useful for:
# * Output of USPEX calculations
# * Fingerprints

# %% [markdown]
# ### <span style="font-family:Menlo;">Pandas</span> (beginners and advanced)
# <img src="pic/pandas_logo.png" alt="Pandas logo"/>
#
#
# #### <span style="font-family:Menlo;">Pandas</span> is a library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# [Link](https://github.com/jorisvandenbossche/pandas-tutorial) to Pandas tutorials

# %% [markdown]
# ### Video of <span style="font-family:Menlo;">Pandas</span> tutorials

# %%
# Beginners
YouTubeVideo('Cz_u2If7KbI')

# %%
# Advanced
YouTubeVideo('gS7kVg-4ZaU')

# %% [markdown]
# ### Useful for:
# * Zahed's projects with huge amount of data

# %% [markdown]
# ### <span style="font-family:Menlo;">Git</span> (beginners)
# <img src="pic/git_logo.png" alt="Git logo" style="width: 100px;"/>
#
# #### <span style="font-family:Menlo;">Git</span> is distributed version control system designed to handle everything from small to very large projects with speed and efficiency.

# %% [markdown]
# ### Video of <span style="font-family:Menlo;">Git</span> tutorials

# %%
YouTubeVideo('mkQzl2v7BuI')

# %% [markdown]
# ### Useful for:
# * Any project with >2 developers and >1000 lines of code

# %% [markdown]
# ### <span style="font-family:Menlo;">Scikit-learn</span> (beginners and advanced)
# <img src="pic/scikit-learn_logo.png" alt="Scikit-learn logo" style="width: 100px;"/>
#
# #### Machine Learning package in Python
#
# * Simple and efficient tools for data mining and data analysis
# * Accessible to everybody, and reusable in various contexts
# * Built on NumPy, SciPy, and matplotlib
# * Open source, commercially usable - BSD license

# %% [markdown]
# ### Video of <span style="font-family:Menlo;">Scikit-learn</span> tutorials

# %%
# Beginners
YouTubeVideo('Vs7tdobwj1k')

# %%
# Advanced
YouTubeVideo('0eYOhEF_aK0')

# %% [markdown]
# ## Testing and test coverage

# %% [markdown]
# #### Lecture about testing

# %%
YouTubeVideo('HTSUCJn1NCA')

# %% [markdown]
# #### Test coverage
#
# ##### It is libraries/scripts that return the value of lines of code that covered by tests, like
#
# * [Coverage.py](https://coverage.readthedocs.io/en/coverage-4.4.1/)
# * [Coveralls](https://github.com/z4r/python-coveralls)

# %%
YouTubeVideo('qTgk2DUM6G0?t=8m32s')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/qTgk2DUM6G0?t=8m32s"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Useful for:
# * Any project with >2 developers and >1000 lines of code

# %% [markdown]
# ## Cython

# %% [markdown]
# <img src="pic/cython_logo.png" alt="Cython logo" style="width: 100px;"/>
# ### <span style="font-family:Menlo;">Cython</span> is an optimising static compiler for both the Python programming language and the extended Cython programming language (based on Pyrex). It makes writing C extensions for Python as easy as Python itself

# %%
YouTubeVideo('vl9La7wH7QI')

# %% [markdown]
# ### Useful for:
# * <span style="font-family:Menlo;">Softmodes</span> code optimization
# * <span style="font-family:Menlo;">Topological random</span> code optimization
# * <span style="font-family:Menlo;">Fingerprints</span> code optimization

# %% [markdown]
# ## Multicore computing

# %% [markdown]
# ### Useful for:
# * Parallel submission and postprocessing structures for each generation.
# ##### Maybe:
# * <span style="font-family:Menlo;">Fingerprints</span> calculations
# * Applying variational operators to a strucutes.

# %%
YouTubeVideo('WSEi_a2k19c')

# %% [markdown]
# ## Some specific topics

# %% [markdown]
# ### Making presentation in <span style="font-family:Menlo;">Python notebook</span>

# %% [markdown]
# <span style="font-family:Menlo;"></span>

# %% [markdown]
# <span style="font-family:Menlo;"></span>

# %% [markdown]
# <span style="font-family:Menlo;"></span>

# %% [markdown]
# ### More useful references
#
# 1. [EuroSciPy YouTube channel](https://www.youtube.com/channel/UCruMegFU9dg2doEGOUaAWTg)
# 2. [SciPy lectures](http://www.scipy-lectures.org/intro/index.html)
# 3. Book <span style="font-family:xcdc;">Effective computation in physics</span>
# <img src="pic/EffectiveComputingInPhysics.jpeg" alt="Effective computing in Physics"/>

# %% [markdown]
# # Thank you for your attention
